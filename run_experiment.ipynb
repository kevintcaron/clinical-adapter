# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/DL/DL\ project\ /clinical-adapter
# Out:
# /content/drive/MyDrive/DL/DL project /clinical-adapter

# %%
# !unzip Data.zip

# %%
# !pip install -q spacy
# !pip install -q evaluate
# !pip install -q datasets
# !pip install -q accelerate
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_ner_bc5cdr_md-0.4.0.tar.gz
# !pip install -Uq adapters
# !pip install -q seqeval
# !pip install wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 MB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 659.5/659.5 kB 27.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 11.5 MB/s eta 0:00:00
# ...

# %%
# !python run_experiment.py
# Out:
# 2023-12-04 14:57:48.319799: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-04 14:57:48.319868: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-04 14:57:48.319904: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-04 14:57:49.492912: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# Arguments:
# config: ./config.yaml
# task: ast
# model: bert
# finetune: head
# lr: 1e-05
# epochs: 2
# batch: 16
# weight_decay: 0.002
# adapter: False
# adapter_method: SeqBnConfig
# reduction_factor: 64
# ...

# %%
# to run hyperparameter tuning
#Define hyperparameters here
#sample used for bert_head_ner
import wandb
sweep_configuration = {
  "method": "random",
  "metric": {
    "goal": "maximize",
    "name": "accuracy"
  },
  "parameters": {
    "batch": {
      "max": 108,
      "min": 7,
      "distribution": "int_uniform"
    },
    "epochs": {
      "max": 66,
      "min": 1,
      "distribution": "int_uniform"
    },
    "lr": {
      "max": 0.00028526469857312884,
      "min": 0.000005,
      "distribution": "uniform"
    },
    "weight_decay": {
      "max": 0.04744433799737011,
      "min": 0.001,
      "distribution": "uniform"
    }
  }
}

sweep_id = wandb.sweep(sweep=sweep_configuration, project="clinical-adapter")

# %%
#replace below with sweep_id from above
# !wandb agent clinical-adapter/clinical-adapter/{sweep_id}
